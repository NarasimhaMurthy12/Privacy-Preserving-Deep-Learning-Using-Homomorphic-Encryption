# %% [markdown]
# Implementation of Deep Net with 1 hidden layer

# %%
pip install tenseal
# Out:
# Collecting tenseal
#   Downloading tenseal-0.3.16-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Downloading tenseal-0.3.16-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 70.6 MB/s eta 0:00:00
# Installing collected packages: tenseal
# Successfully installed tenseal-0.3.16
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import tenseal as ts
import pandas as pd
import random
from time import time

# those are optional and are not necessary for training
import numpy as np
import matplotlib.pyplot as plt

# %%
torch.random.manual_seed(73)
random.seed(73)


def split_train_test(x, y, test_ratio=0.3):
    idxs = [i for i in range(len(x))]
    random.shuffle(idxs)
    # delimiter between test and train data
    delim = int(len(x) * test_ratio)
    test_idxs, train_idxs = idxs[:delim], idxs[delim:]
    return x[train_idxs], y[train_idxs], x[test_idxs], y[test_idxs]


def heart_disease_data():
    data = pd.read_csv("/kaggle/input/trydataset1/framingham.csv")
    # drop rows with missing values
    data = data.dropna()
    # drop some features
    data = data.drop(columns=["education", "currentSmoker", "BPMeds", "diabetes", "diaBP", "BMI"])
    # balance data
    grouped = data.groupby('TenYearCHD')
    data = grouped.apply(lambda x: x.sample(grouped.size().min(), random_state=73).reset_index(drop=True))
    # extract labels
    y = torch.tensor(data["TenYearCHD"].values).float().unsqueeze(1)
    #data = data.drop("TenYearCHD",'columns')
    # standardize data
    data = (data - data.mean()) / data.std()
    x = torch.tensor(data.values).float()
    return split_train_test(x, y)


def random_data(m=1024, n=2):
    # data separable by the line `y = x`
    x_train = torch.randn(m, n)
    x_test = torch.randn(m // 2, n)
    y_train = (x_train[:, 0] >= x_train[:, 1]).float().unsqueeze(0).t()
    y_test = (x_test[:, 0] >= x_test[:, 1]).float().unsqueeze(0).t()
    return x_train, y_train, x_test, y_test


# You can use whatever data you want without modification to the tutorial
# x_train, y_train, x_test, y_test = random_data()
x_train, y_train, x_test, y_test = heart_disease_data()

print("############# Data summary #############")
print(f"x_train has shape: {x_train.shape}")
print(f"y_train has shape: {y_train.shape}")
print(f"x_test has shape: {x_test.shape}")
print(f"y_test has shape: {y_test.shape}")
print("#######################################")
# Out:
# ############# Data summary #############
# x_train has shape: torch.Size([780, 10])
# y_train has shape: torch.Size([780, 1])
# x_test has shape: torch.Size([334, 10])
# y_test has shape: torch.Size([334, 1])
# #######################################
# <ipython-input-3-9c1daa9f64ab>:22: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   data = grouped.apply(lambda x: x.sample(grouped.size().min(), random_state=73).reset_index(drop=True))

# %%
# parameters
poly_mod_degree = 8192
coeff_mod_bit_sizes = [40, 21, 21, 21, 21, 21, 21, 40]
# create TenSEALContext
ctx_training = ts.context(ts.SCHEME_TYPE.CKKS, poly_mod_degree, -1, coeff_mod_bit_sizes)
ctx_training.global_scale = 2 ** 21
ctx_training.generate_galois_keys()

# %%
#t_start = time()
#enc_x_train = ts.ckks_tensor(ctx_training, x_train[0:300])
#enc_y_train = ts.ckks_tensor(ctx_training, y_train[0:300])
#t_end = time()
#print(f"Encryption of the training_set took {int(t_end - t_start)} seconds")

# %%
class EncryptedDL1layer() :
  def __init__(self) -> None:
      self.weight1=np.random.rand(10,3)*0.01
      self.bias1=np.random.rand(3)*0.01
      self.weight2=np.random.rand(3, 1)*0.01
      self.bias2=np.random.rand(1)*0.01
      self.dw1=0
      self.db1=0
      self.dw2=0
      self.db2=0
  def bootstrapping(enc,ctx_training) :
    return ts.ckks_tensor(ctx_training,enc.decrypt())
  def sigmoid(enc_x):
    return enc_x.polyval([0.5, 0.197, 0, -0.004])
  def sigmoid_derv(enc_x):
    return enc_x.polyval([0.197,0,-0.012,0])
  def forward(self,enc_x_train,ctx_training) :
    z11=enc_x_train.mm(self.weight1)
    z1=z11.add(self.bias1)
    a1=EncryptedDL1layer.sigmoid(z1)
    y=EncryptedDL1layer.bootstrapping(a1,ctx_training)
    z21=y.mm(self.weight2)
    z2=z21.add(self.bias2)
    a2=EncryptedDL1layer.sigmoid(z2)
    return a2,z2,a1,z1
  def backward(self,a2,z2,a1,z1,enc_y_train,ctx_training) :
    #calculating the output at the layer 2
    error=a2-enc_y_train
    der=EncryptedDL1layer.sigmoid_derv(z2)
    #finding delta2
    delta2=error.mul(der)
    #using bootstrapping
    delta2=EncryptedDL1layer.bootstrapping(delta2,ctx_training)
    #finding delta1
    del1=delta2.mm(self.weight2.transpose())
    del1=EncryptedDL1layer.bootstrapping(del1,ctx_training)
    #finding der1
    der1=EncryptedDL1layer.sigmoid_derv(z1)
    #using bootstrapping
    der1=EncryptedDL1layer.bootstrapping(der1,ctx_training)
    #finding delta1
    delta1=del1.mul(der1)
    #finding the gradients
    #for weight2 and bias2
    self.dw2=a1.transpose().mm(delta2)
    self.db2=delta2.sum()
    #for weight1 and bias1
    self.dw1=enc_x_train.transpose().mm(delta1)
    self.db1=delta1.sum()
  def update_params(self):
    self.weight2=self.weight2-0.01*self.dw2
    self.bias2=self.bias2-0.01*self.db2
    self.weight1=self.weight1-0.01*self.dw1
    self.bias1=self.bias1-0.01*self.db1
  def encrypt(self, context):
    self.weight1 = ts.ckks_tensor(context, self.weight1)
    self.bias1 = ts.ckks_tensor(context, self.bias1)
    self.weight2 = ts.ckks_tensor(context, self.weight2)
    self.bias2 = ts.ckks_tensor(context, self.bias2)
  def decrypt(self):
    self.weight1 = self.weight1.decrypt()
    self.bias1 = self.bias1.decrypt()
    self.weight2 = self.weight2.decrypt()
    self.bias2 = self.bias2.decrypt()
  def accuracy(self,x_test,y_test):
    #self.decrypt()
    w1 = torch.tensor(self.weight1)
    b1 = torch.tensor(self.bias1)
    out1 = torch.sigmoid(x_test.matmul(w1) + b1).reshape(-1, 1)
    w2 = torch.tensor(self.weight2)
    b2 = torch.tensor(self.bias2)
    out2 = torch.sigmoid(out1.matmul(w2) + b2).reshape(-1, 1)
    correct = torch.abs(y_test - out2) < 0.5
    return correct.float().mean()

# %%
EPOCHS = 10
eelr = EncryptedDL1layer()
times = []
for epoch in range(EPOCHS):
    print("Epoch : ",epoch)
    for i in range(0,780,60):
        t_start = time()
        enc_x_train = ts.ckks_tensor(ctx_training, x_train[i:i+60])
        enc_y_train = ts.ckks_tensor(ctx_training, y_train[i:i+60])
        t_end = time()
        print(f"Encryption of the training_set took {int(t_end - t_start)} seconds")
        print("Batch : ",i/60)
        eelr.encrypt(ctx_training)
        t_start = time()
        a2,z2,a1,z1 = eelr.forward(enc_x_train,ctx_training)
        eelr.backward(a2,z2,a1,z1,enc_y_train,ctx_training)
        eelr.update_params()
        t_end = time()    
        eelr.decrypt()
        print("\n")
        print("Time taken for this batch : ",t_end - t_start)
    times.append(t_end - t_start)
    a2,z2,a1,z1 = eelr.forward(enc_x_train,ctx_training)
    data=torch.tensor(a2.decrypt().tolist())
    loss_fn = torch.nn.BCEWithLogitsLoss()
    loss = loss_fn(data, y_train[i:i+60])
    print("Loss at epoch ",epoch,loss.data)
    out=torch.tensor(enc_y_train.sub(a2).decrypt().tolist())
    correct=torch.abs(out)<0.5
    print("Accuracy at epoch ",epoch,correct.float().mean())
print(f"\nAverage time per epoch: {int(sum(times) / len(times))} seconds")
print("Final weight1 ",eelr.weight1.tolist())
print("Final bias 1",eelr.bias1.tolist())
print("Final weight 2",eelr.weight2.tolist())
print("Final bias 2",eelr.bias2.tolist())
# Out:
# Epoch :  0
# Encryption of the training_set took 4 seconds
# Batch :  0.0
#
#
# Time taken for this batch :  51.815240144729614
# Encryption of the training_set took 2 seconds
# Batch :  1.0
#
#
# Time taken for this batch :  49.06419014930725
# Encryption of the training_set took 2 seconds
# Batch :  2.0
#
#
# Time taken for this batch :  48.29347825050354
# Encryption of the training_set took 2 seconds
# Batch :  3.0
#
#
# Time taken for this batch :  48.819936752319336
# Encryption of the training_set took 2 seconds
# Batch :  4.0
#
#
# Time taken for this batch :  49.2901406288147
# Encryption of the training_set took 2 seconds
# Batch :  5.0
#
#
# Time taken for this batch :  48.48014998435974
# Encryption of the training_set took 2 seconds
# Batch :  6.0
#
#
# Time taken for this batch :  49.65142822265625
# Encryption of the training_set took 2 seconds
# Batch :  7.0
#
#
# Time taken for this batch :  48.88833713531494
# Encryption of the training_set took 3 seconds
# Batch :  8.0
#
#
# Time taken for this batch :  49.871458530426025
# Encryption of the training_set took 2 seconds
# Batch :  9.0
#
#
# Time taken for this batch :  49.83101987838745
# Encryption of the training_set took 2 seconds
# Batch :  10.0
#
#
# Time taken for this batch :  48.311809062957764
# Encryption of the training_set took 2 seconds
# Batch :  11.0
#
#
# Time taken for this batch :  48.755584955215454
# Encryption of the training_set took 2 seconds
# Batch :  12.0
#
#
# Time taken for this batch :  48.547399044036865
# Loss at epoch  0 tensor(0.7156)
# Accuracy at epoch  0 tensor(0.4667)
# Epoch :  1
# Encryption of the training_set took 2 seconds
# Batch :  0.0
#
#
# Time taken for this batch :  48.39680624008179
# Encryption of the training_set took 2 seconds
# Batch :  1.0
#
#
# Time taken for this batch :  48.6863477230072
# Encryption of the training_set took 2 seconds
# Batch :  2.0
#
#
# Time taken for this batch :  49.62800574302673
# Encryption of the training_set took 2 seconds
# Batch :  3.0
#
#
# Time taken for this batch :  48.10827422142029
# Encryption of the training_set took 2 seconds
# Batch :  4.0
#
#
# Time taken for this batch :  49.49785089492798
# Encryption of the training_set took 3 seconds
# Batch :  5.0
#
#
# Time taken for this batch :  49.81366586685181
# Encryption of the training_set took 3 seconds
# Batch :  6.0
#
#
# Time taken for this batch :  50.05158066749573
# Encryption of the training_set took 3 seconds
# Batch :  7.0
#
#
# Time taken for this batch :  53.036436557769775
# Encryption of the training_set took 3 seconds
# Batch :  8.0
#
#
# Time taken for this batch :  51.6654372215271
# Encryption of the training_set took 3 seconds
# Batch :  9.0
#
#
# Time taken for this batch :  51.17363715171814
# Encryption of the training_set took 3 seconds
# Batch :  10.0
#
#
# Time taken for this batch :  51.807395935058594
# Encryption of the training_set took 3 seconds
# Batch :  11.0
#
#
# Time taken for this batch :  51.8915741443634
# Encryption of the training_set took 3 seconds
# Batch :  12.0
#
#
# Time taken for this batch :  51.43214011192322
# Loss at epoch  1 tensor(0.7159)
# Accuracy at epoch  1 tensor(0.4833)
# Epoch :  2
# Encryption of the training_set took 3 seconds
# Batch :  0.0
#
#
# Time taken for this batch :  50.28338050842285
# Encryption of the training_set took 3 seconds
# Batch :  1.0
#
#
# Time taken for this batch :  49.87141704559326
# Encryption of the training_set took 3 seconds
# Batch :  2.0
#
#
# Time taken for this batch :  50.24870491027832
# Encryption of the training_set took 3 seconds
# Batch :  3.0
#
#
# Time taken for this batch :  50.71462416648865
# Encryption of the training_set took 3 seconds
# Batch :  4.0
#
#
# Time taken for this batch :  50.69858145713806
# Encryption of the training_set took 2 seconds
# Batch :  5.0
#
#
# Time taken for this batch :  48.732587575912476
# Encryption of the training_set took 3 seconds
# Batch :  6.0
#
#
# Time taken for this batch :  47.871339321136475
# Encryption of the training_set took 2 seconds
# Batch :  7.0
#
#
# Time taken for this batch :  48.911754846572876
# Encryption of the training_set took 2 seconds
# Batch :  8.0
#
#
# Time taken for this batch :  48.27076721191406
# Encryption of the training_set took 2 seconds
# Batch :  9.0
#
#
# Time taken for this batch :  49.50968551635742
# Encryption of the training_set took 2 seconds
# Batch :  10.0
#
#
# Time taken for this batch :  48.579185009002686
# Encryption of the training_set took 3 seconds
# Batch :  11.0
#
#
# Time taken for this batch :  47.85907173156738
# Encryption of the training_set took 2 seconds
# Batch :  12.0
#
#
# Time taken for this batch :  50.26816534996033
# Loss at epoch  2 tensor(0.7159)
# Accuracy at epoch  2 tensor(0.5000)
# Epoch :  3
# Encryption of the training_set took 2 seconds
# Batch :  0.0
#
#
# Time taken for this batch :  51.11657500267029
# Encryption of the training_set took 3 seconds
# Batch :  1.0
#
#
# Time taken for this batch :  50.46451139450073
# Encryption of the training_set took 3 seconds
# Batch :  2.0
#
#
# Time taken for this batch :  50.05835843086243
# Encryption of the training_set took 2 seconds
# Batch :  3.0
#
#
# Time taken for this batch :  49.46073079109192
# Encryption of the training_set took 2 seconds
# Batch :  4.0
#
#
# Time taken for this batch :  48.7811598777771
# Encryption of the training_set took 2 seconds
# Batch :  5.0
#
#
# Time taken for this batch :  49.321085929870605
# Encryption of the training_set took 2 seconds
# Batch :  6.0
#
#
# Time taken for this batch :  48.28671741485596
# Encryption of the training_set took 2 seconds
# Batch :  7.0
#
#
# Time taken for this batch :  48.28091311454773
# Encryption of the training_set took 2 seconds
# Batch :  8.0
#
#
# Time taken for this batch :  48.38322877883911
# Encryption of the training_set took 2 seconds
# Batch :  9.0
#
#
# Time taken for this batch :  47.35557174682617
# Encryption of the training_set took 2 seconds
# Batch :  10.0
#
#
# Time taken for this batch :  48.08955407142639
# Encryption of the training_set took 2 seconds
# Batch :  11.0
#
#
# Time taken for this batch :  47.623051404953
# Encryption of the training_set took 2 seconds
# Batch :  12.0
#
#
# Time taken for this batch :  47.96724486351013
# Loss at epoch  3 tensor(0.7158)
# Accuracy at epoch  3 tensor(0.5500)
# Epoch :  4
# Encryption of the training_set took 3 seconds
# Batch :  0.0
#
#
# Time taken for this batch :  48.58469748497009
# Encryption of the training_set took 3 seconds
# Batch :  1.0
#
#
# Time taken for this batch :  49.185089111328125
# Encryption of the training_set took 2 seconds
# Batch :  2.0
#
#
# Time taken for this batch :  48.24879717826843
# Encryption of the training_set took 2 seconds
# Batch :  3.0
#
#
# Time taken for this batch :  48.92144775390625
# Encryption of the training_set took 2 seconds
# Batch :  4.0
#
#
# Time taken for this batch :  48.60305309295654
# Encryption of the training_set took 2 seconds
# Batch :  5.0
#
#
# Time taken for this batch :  51.20919227600098
# Encryption of the training_set took 3 seconds
# Batch :  6.0
#
#
# Time taken for this batch :  51.96647334098816
# Encryption of the training_set took 3 seconds
# Batch :  7.0
#
#
# Time taken for this batch :  52.87446594238281
# Encryption of the training_set took 3 seconds
# Batch :  8.0
#
#
# Time taken for this batch :  53.05415201187134
# Encryption of the training_set took 3 seconds
# Batch :  9.0
#
#
# Time taken for this batch :  53.336440563201904
# Encryption of the training_set took 3 seconds
# Batch :  10.0
#
#
# Time taken for this batch :  52.85084319114685
# Encryption of the training_set took 3 seconds
# Batch :  11.0
#
#
# Time taken for this batch :  51.898054361343384
# Encryption of the training_set took 3 seconds
# Batch :  12.0
#
#
# Time taken for this batch :  52.264853715896606
# Loss at epoch  4 tensor(0.7159)
# Accuracy at epoch  4 tensor(0.5333)
# Epoch :  5
# Encryption of the training_set took 3 seconds
# Batch :  0.0
#
#
# Time taken for this batch :  51.59123659133911
# Encryption of the training_set took 3 seconds
# Batch :  1.0
#
#
# Time taken for this batch :  51.25521159172058
# Encryption of the training_set took 3 seconds
# Batch :  2.0
#
#
# Time taken for this batch :  50.83761215209961
# Encryption of the training_set took 3 seconds
# Batch :  3.0
#
#
# Time taken for this batch :  51.03464150428772
# Encryption of the training_set took 3 seconds
# Batch :  4.0
#
#
# Time taken for this batch :  51.75696086883545
# Encryption of the training_set took 3 seconds
# Batch :  5.0
#
#
# Time taken for this batch :  52.2846953868866
# Encryption of the training_set took 3 seconds
# Batch :  6.0
#
#
# Time taken for this batch :  51.43972706794739
# Encryption of the training_set took 3 seconds
# Batch :  7.0
#
#
# Time taken for this batch :  51.35226631164551
# Encryption of the training_set took 2 seconds
# Batch :  8.0
#
#
# Time taken for this batch :  51.40861392021179
# Encryption of the training_set took 3 seconds
# Batch :  9.0
#
#
# Time taken for this batch :  50.86371064186096
# Encryption of the training_set took 3 seconds
# Batch :  10.0
#
#
# Time taken for this batch :  51.34112739562988
# Encryption of the training_set took 3 seconds
# Batch :  11.0
#
#
# Time taken for this batch :  52.180423736572266
# Encryption of the training_set took 3 seconds
# Batch :  12.0
#
#
# Time taken for this batch :  50.49169373512268
# Loss at epoch  5 tensor(0.7151)
# Accuracy at epoch  5 tensor(0.5500)
# Epoch :  6
# Encryption of the training_set took 3 seconds
# Batch :  0.0
#
#
# Time taken for this batch :  50.18649673461914
# Encryption of the training_set took 3 seconds
# Batch :  1.0
#
#
# Time taken for this batch :  50.77195501327515
# Encryption of the training_set took 3 seconds
# Batch :  2.0
#
#
# Time taken for this batch :  51.909263134002686
# Encryption of the training_set took 3 seconds
# Batch :  3.0
#
#
# Time taken for this batch :  50.58192706108093
# Encryption of the training_set took 3 seconds
# Batch :  4.0
#
#
# Time taken for this batch :  50.36729550361633
# Encryption of the training_set took 3 seconds
# Batch :  5.0
#
#
# Time taken for this batch :  51.99502396583557
# Encryption of the training_set took 3 seconds
# Batch :  6.0
#
#
# Time taken for this batch :  50.23490023612976
# Encryption of the training_set took 3 seconds
# Batch :  7.0
#
#
# Time taken for this batch :  50.10157322883606
# Encryption of the training_set took 3 seconds
# Batch :  8.0
#
#
# Time taken for this batch :  50.76986742019653
# Encryption of the training_set took 3 seconds
# Batch :  9.0
#
#
# Time taken for this batch :  49.18878126144409
# Encryption of the training_set took 3 seconds
# Batch :  10.0
#
#
# Time taken for this batch :  48.93064641952515
# Encryption of the training_set took 2 seconds
# Batch :  11.0
#
#
# Time taken for this batch :  48.97660517692566
# Encryption of the training_set took 2 seconds
# Batch :  12.0
#
#
# Time taken for this batch :  48.97845387458801
# Loss at epoch  6 tensor(0.7134)
# Accuracy at epoch  6 tensor(0.6500)
# Epoch :  7
# Encryption of the training_set took 2 seconds
# Batch :  0.0
#
#
# Time taken for this batch :  49.610777854919434
# Encryption of the training_set took 3 seconds
# Batch :  1.0
#
#
# Time taken for this batch :  50.40363621711731
# Encryption of the training_set took 3 seconds
# Batch :  2.0
#
#
# Time taken for this batch :  50.39846992492676
# Encryption of the training_set took 2 seconds
# Batch :  3.0
#
#
# Time taken for this batch :  48.7675085067749
# Encryption of the training_set took 2 seconds
# Batch :  4.0
#
#
# Time taken for this batch :  48.83626055717468
# Encryption of the training_set took 2 seconds
# Batch :  5.0
#
#
# Time taken for this batch :  48.89904737472534
# Encryption of the training_set took 3 seconds
# Batch :  6.0
#
#
# Time taken for this batch :  49.04152226448059
# Encryption of the training_set took 2 seconds
# Batch :  7.0
#
#
# Time taken for this batch :  50.38652324676514
# Encryption of the training_set took 2 seconds
# Batch :  8.0
#
#
# Time taken for this batch :  48.92505669593811
# Encryption of the training_set took 2 seconds
# Batch :  9.0
#
#
# Time taken for this batch :  50.52696633338928
# Encryption of the training_set took 3 seconds
# Batch :  10.0
#
#
# Time taken for this batch :  50.91696548461914
# Encryption of the training_set took 3 seconds
# Batch :  11.0
#
#
# Time taken for this batch :  51.8311071395874
# Encryption of the training_set took 3 seconds
# Batch :  12.0
#
#
# Time taken for this batch :  52.6461296081543
# Loss at epoch  7 tensor(0.7086)
# Accuracy at epoch  7 tensor(0.8500)
# Epoch :  8
# Encryption of the training_set took 3 seconds
# Batch :  0.0
#
#
# Time taken for this batch :  49.916876792907715
# Encryption of the training_set took 3 seconds
# Batch :  1.0
#
#
# Time taken for this batch :  50.771538972854614
# Encryption of the training_set took 2 seconds
# Batch :  2.0
#
#
# Time taken for this batch :  49.36109447479248
# Encryption of the training_set took 3 seconds
# Batch :  3.0
#
#
# Time taken for this batch :  48.676634788513184
# Encryption of the training_set took 2 seconds
# Batch :  4.0
#
#
# Time taken for this batch :  49.15838837623596
# Encryption of the training_set took 2 seconds
# Batch :  5.0
#
#
# Time taken for this batch :  48.66357612609863
# Encryption of the training_set took 2 seconds
# Batch :  6.0
#
#
# Time taken for this batch :  48.23478984832764
# Encryption of the training_set took 2 seconds
# Batch :  7.0
#
#
# Time taken for this batch :  47.978407859802246
# Encryption of the training_set took 2 seconds
# Batch :  8.0
#
#
# Time taken for this batch :  48.601876735687256
# Encryption of the training_set took 2 seconds
# Batch :  9.0
#
#
# Time taken for this batch :  47.97995448112488
# Encryption of the training_set took 2 seconds
# Batch :  10.0
#
#
# Time taken for this batch :  49.5570604801178
# Encryption of the training_set took 3 seconds
# Batch :  11.0
#
#
# Time taken for this batch :  50.62778306007385
# Encryption of the training_set took 3 seconds
# Batch :  12.0
#
#
# Time taken for this batch :  49.78124237060547
# Loss at epoch  8 tensor(0.6964)
# Accuracy at epoch  8 tensor(0.9000)
# Epoch :  9
# Encryption of the training_set took 3 seconds
# Batch :  0.0
#
#
# Time taken for this batch :  49.33416748046875
# Encryption of the training_set took 2 seconds
# Batch :  1.0
#
#
# Time taken for this batch :  50.765079975128174
# Encryption of the training_set took 2 seconds
# Batch :  2.0
#
#
# Time taken for this batch :  49.735215187072754
# Encryption of the training_set took 3 seconds
# Batch :  3.0
#
#
# Time taken for this batch :  48.982476234436035
# Encryption of the training_set took 2 seconds
# Batch :  4.0
#
#
# Time taken for this batch :  49.78055667877197
# Encryption of the training_set took 3 seconds
# Batch :  5.0
#
#
# Time taken for this batch :  49.6072564125061
# Encryption of the training_set took 3 seconds
# Batch :  6.0
#
#
# Time taken for this batch :  50.5828332901001
# Encryption of the training_set took 3 seconds
# Batch :  7.0
#
#
# Time taken for this batch :  50.670583963394165
# Encryption of the training_set took 3 seconds
# Batch :  8.0
#
#
# Time taken for this batch :  49.519622802734375
# Encryption of the training_set took 2 seconds
# Batch :  9.0
#
#
# Time taken for this batch :  49.27554488182068
# Encryption of the training_set took 2 seconds
# Batch :  10.0
#
#
# Time taken for this batch :  49.404860496520996
# Encryption of the training_set took 2 seconds
# Batch :  11.0
#
#
# Time taken for this batch :  49.36667537689209
# Encryption of the training_set took 3 seconds
# Batch :  12.0
#
#
# Time taken for this batch :  51.236687660217285
# Loss at epoch  9 tensor(0.6718)
# Accuracy at epoch  9 tensor(1.)
#
# Average time per epoch: 50 seconds
# Final weight1  [[0.06648817304782817, -0.07705781870106622, 0.08300491417463697], [0.12380830308786783, -0.08634721719968315, 0.13862883721044092], [0.022673515264311703, -0.06925615043578034, 0.08825464904215406], [0.049520196339201156, -0.04581448373459571, 0.06895203550979945], [0.1019423241380933, -0.0942641747134521, 0.12967876813265183], [0.03149416340658951, -0.051985353926938364, 0.07813291199238845], [0.1363951829363971, -0.1440372675536364, 0.1326728087678332], [-0.013674813150720812, -0.024753634054980364, 0.049262676202181714], [0.06327197634777501, -0.019279132611944312, 0.04158376793943717], [0.4155805400541925, -0.5464997970075164, 0.5822525633329745]]
# Final bias 1 [-0.01525555353403431, 0.019075205275550497, 0.01126642217032375]
# Final weight 2 [[0.5101545111534864], [-0.7698887376087568], [0.7002429940772832]]
# Final bias 2 [-0.17342590605144473]

# %%
print(eelr.weight1.tolist())
print(eelr.bias1.tolist())
print(eelr.weight2.tolist())
print(eelr.bias2.tolist())
# Out:
# [[0.06648817304782817, -0.07705781870106622, 0.08300491417463697], [0.12380830308786783, -0.08634721719968315, 0.13862883721044092], [0.022673515264311703, -0.06925615043578034, 0.08825464904215406], [0.049520196339201156, -0.04581448373459571, 0.06895203550979945], [0.1019423241380933, -0.0942641747134521, 0.12967876813265183], [0.03149416340658951, -0.051985353926938364, 0.07813291199238845], [0.1363951829363971, -0.1440372675536364, 0.1326728087678332], [-0.013674813150720812, -0.024753634054980364, 0.049262676202181714], [0.06327197634777501, -0.019279132611944312, 0.04158376793943717], [0.4155805400541925, -0.5464997970075164, 0.5822525633329745]]
# [-0.01525555353403431, 0.019075205275550497, 0.01126642217032375]
# [[0.5101545111534864], [-0.7698887376087568], [0.7002429940772832]]
# [-0.17342590605144473]

# %%
#eelr.encrypt(ctx_training)
j,k,l,r=eelr.forward(enc_x_train,ctx_training)
#enc_y_train.sub(j).decrypt().tolist()

# %%
out=torch.tensor(enc_y_train.sub(j).decrypt().tolist())
correct=torch.abs(out)<0.5
print(correct.float().mean())
# Out:
# tensor(1.)

# %%
enc_x_test = ts.ckks_tensor(ctx_training, x_test)
enc_y_test = ts.ckks_tensor(ctx_training, y_test)

# %%
m,n,j,k=eelr.forward(enc_x_test,ctx_training)
out=torch.tensor(enc_y_test.sub(m).decrypt().tolist())
correct=torch.abs(out)<0.5
print(correct.float().mean())
# Out:
# tensor(0.9850)
