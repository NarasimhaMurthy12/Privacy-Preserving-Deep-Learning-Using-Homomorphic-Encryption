# %% [markdown]
# Implementation of Deep Net with 1 hidden layer

# %%
pip install tenseal
# Out:
# Collecting tenseal
#   Downloading tenseal-0.3.16-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Downloading tenseal-0.3.16-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 37.8 MB/s eta 0:00:00
# Installing collected packages: tenseal
# Successfully installed tenseal-0.3.16
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import tenseal as ts
import pandas as pd
import random
from time import time

# those are optional and are not necessary for training
import numpy as np
import matplotlib.pyplot as plt

# %%
torch.random.manual_seed(73)
random.seed(73)


def split_train_test(x, y, test_ratio=0.3):
    idxs = [i for i in range(len(x))]
    random.shuffle(idxs)
    # delimiter between test and train data
    delim = int(len(x) * test_ratio)
    test_idxs, train_idxs = idxs[:delim], idxs[delim:]
    return x[train_idxs], y[train_idxs], x[test_idxs], y[test_idxs]


def heart_disease_data():
    data = pd.read_csv("/kaggle/input/trydata/framingham.csv")
    # drop rows with missing values
    data = data.dropna()
    # drop some features
    data = data.drop(columns=["education", "currentSmoker", "BPMeds", "diabetes", "diaBP", "BMI"])
    # balance data
    grouped = data.groupby('TenYearCHD')
    data = grouped.apply(lambda x: x.sample(grouped.size().min(), random_state=73).reset_index(drop=True))
    # extract labels
    y = torch.tensor(data["TenYearCHD"].values).float().unsqueeze(1)
    #data = data.drop("TenYearCHD",'columns')
    # standardize data
    data = (data - data.mean()) / data.std()
    x = torch.tensor(data.values).float()
    return split_train_test(x, y)


def random_data(m=1024, n=2):
    # data separable by the line `y = x`
    x_train = torch.randn(m, n)
    x_test = torch.randn(m // 2, n)
    y_train = (x_train[:, 0] >= x_train[:, 1]).float().unsqueeze(0).t()
    y_test = (x_test[:, 0] >= x_test[:, 1]).float().unsqueeze(0).t()
    return x_train, y_train, x_test, y_test


# You can use whatever data you want without modification to the tutorial
# x_train, y_train, x_test, y_test = random_data()
x_train, y_train, x_test, y_test = heart_disease_data()

print("############# Data summary #############")
print(f"x_train has shape: {x_train.shape}")
print(f"y_train has shape: {y_train.shape}")
print(f"x_test has shape: {x_test.shape}")
print(f"y_test has shape: {y_test.shape}")
print("#######################################")
# Out:
# ############# Data summary #############
# x_train has shape: torch.Size([780, 10])
# y_train has shape: torch.Size([780, 1])
# x_test has shape: torch.Size([334, 10])
# y_test has shape: torch.Size([334, 1])
# #######################################
# <ipython-input-3-c85f04021ea0>:22: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   data = grouped.apply(lambda x: x.sample(grouped.size().min(), random_state=73).reset_index(drop=True))

# %%
# parameters
poly_mod_degree = 8192
coeff_mod_bit_sizes = [40, 21, 21, 21, 21, 21, 21, 40]
# create TenSEALContext
ctx_training = ts.context(ts.SCHEME_TYPE.CKKS, poly_mod_degree, -1, coeff_mod_bit_sizes)
ctx_training.global_scale = 2 ** 21
ctx_training.generate_galois_keys()

# %%
#t_start = time()
#enc_x_train = ts.ckks_tensor(ctx_training, x_train[0:300])
#enc_y_train = ts.ckks_tensor(ctx_training, y_train[0:300])
#t_end = time()
#print(f"Encryption of the training_set took {int(t_end - t_start)} seconds")

# %%
class EncryptedDL1layer() :
  def __init__(self) -> None:
      self.weight1=np.random.rand(10,3)*0.01
      self.bias1=np.random.rand(3)*0.01
      self.weight2=np.random.rand(3, 1)*0.01
      self.bias2=np.random.rand(1)*0.01
      self.dw1=0
      self.db1=0
      self.dw2=0
      self.db2=0
  def bootstrapping(enc,ctx_training) :
    return ts.ckks_tensor(ctx_training,enc.decrypt())
  def swiss(enc_x):
    return enc_x.polyval([0.6931,0.5,0.125,0])
  def swiss_derv(enc_x):
    return enc_x.polyval([0.5, 0.197, 0, -0.004])
  def forward(self,enc_x_train,ctx_training) :
    z11=enc_x_train.mm(self.weight1)
    z1=z11.add(self.bias1)
    a1=EncryptedDL1layer.swiss(z1)
    y=EncryptedDL1layer.bootstrapping(a1,ctx_training)
    z21=y.mm(self.weight2)
    z2=z21.add(self.bias2)
    a2=EncryptedDL1layer.swiss(z2)
    return a2,z2,a1,z1
  def backward(self,a2,z2,a1,z1,enc_y_train,ctx_training) :
    #calculating the output at the layer 2
    error=a2-enc_y_train
    der=EncryptedDL1layer.swiss_derv(z2)
    #finding delta2
    delta2=error.mul(der)
    #using bootstrapping
    delta2=EncryptedDL1layer.bootstrapping(delta2,ctx_training)
    #finding delta1
    del1=delta2.mm(self.weight2.transpose())
    del1=EncryptedDL1layer.bootstrapping(del1,ctx_training)
    #finding der1
    der1=EncryptedDL1layer.swiss_derv(z1)
    #using bootstrapping
    der1=EncryptedDL1layer.bootstrapping(der1,ctx_training)
    #finding delta1
    delta1=del1.mul(der1)
    #finding the gradients
    #for weight2 and bias2
    self.dw2=a1.transpose().mm(delta2)
    self.db2=delta2.sum()
    #for weight1 and bias1
    self.dw1=enc_x_train.transpose().mm(delta1)
    self.db1=delta1.sum()
  def update_params(self):
    self.weight2=self.weight2-0.01*self.dw2
    self.bias2=self.bias2-0.01*self.db2
    self.weight1=self.weight1-0.01*self.dw1
    self.bias1=self.bias1-0.01*self.db1
  def encrypt(self, context):
    self.weight1 = ts.ckks_tensor(context, self.weight1)
    self.bias1 = ts.ckks_tensor(context, self.bias1)
    self.weight2 = ts.ckks_tensor(context, self.weight2)
    self.bias2 = ts.ckks_tensor(context, self.bias2)
  def decrypt(self):
    self.weight1 = self.weight1.decrypt()
    self.bias1 = self.bias1.decrypt()
    self.weight2 = self.weight2.decrypt()
    self.bias2 = self.bias2.decrypt()
  def accuracy(self,x_test,y_test):
    #self.decrypt()
    w1 = torch.tensor(self.weight1)
    b1 = torch.tensor(self.bias1)
    out1 = torch.swiss(x_test.matmul(w1) + b1).reshape(-1, 1)
    w2 = torch.tensor(self.weight2)
    b2 = torch.tensor(self.bias2)
    out2 = torch.swiss(out1.matmul(w2) + b2).reshape(-1, 1)
    correct = torch.abs(y_test - out2) < 0.5
    return correct.float().mean()

# %%
EPOCHS = 10
eelr = EncryptedDL1layer()
times = []
for epoch in range(EPOCHS):
    print("Epoch : ",epoch)
    t_start = time()
    for i in range(0,780,60):
        print("Batch : ",i/60)
        t_start = time()
        enc_x_train = ts.ckks_tensor(ctx_training, x_train[i:i+60])
        enc_y_train = ts.ckks_tensor(ctx_training, y_train[i:i+60])
        t_end = time()
        print(f"Encryption of the training_batch took {int(t_end - t_start)} seconds")
        eelr.encrypt(ctx_training)
        a2,z2,a1,z1 = eelr.forward(enc_x_train,ctx_training)
        eelr.backward(a2,z2,a1,z1,enc_y_train,ctx_training)
        eelr.update_params()
        t_end = time()
        eelr.decrypt()
        print("Time taken for this batch is : ",t_end - t_start)
    times.append(t_end - t_start)
    a2,z2,a1,z1 = eelr.forward(enc_x_train,ctx_training)
    data=torch.tensor(a2.decrypt().tolist())
    loss_fn = torch.nn.BCEWithLogitsLoss()
    loss = loss_fn(data, y_train[i:i+60])
    print("Loss at epoch ",epoch,loss.data)
    out=torch.tensor(enc_y_train.sub(a2).decrypt().tolist())
    correct=torch.abs(out)<0.5
    print("Accuracy at epoch ",epoch,correct.float().mean())
print(f"\nAverage time per epoch: {int(sum(times) / len(times))} seconds")
print("Final weight1 ",eelr.weight1.tolist())
print("Final bias 1",eelr.bias1.tolist())
print("Final weight 2",eelr.weight2.tolist())
print("Final bias 2",eelr.bias2.tolist())
# Out:
# Epoch :  0
# Batch :  0.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  65.22209787368774
# Batch :  1.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.70484757423401
# Batch :  2.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.77594566345215
# Batch :  3.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.619717597961426
# Batch :  4.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.3128559589386
# Batch :  5.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.34817695617676
# Batch :  6.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.45327949523926
# Batch :  7.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.76766276359558
# Batch :  8.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.948015451431274
# Batch :  9.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  59.91785740852356
# Batch :  10.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.31185746192932
# Batch :  11.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.66811156272888
# Batch :  12.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.57999610900879
# Loss at epoch  0 tensor(0.6764)
# Accuracy at epoch  0 tensor(0.8833)
# Epoch :  1
# Batch :  0.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.7109272480011
# Batch :  1.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.73196864128113
# Batch :  2.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.820868253707886
# Batch :  3.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.35989999771118
# Batch :  4.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  59.69908928871155
# Batch :  5.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  59.465096950531006
# Batch :  6.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  59.79954385757446
# Batch :  7.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  59.983747243881226
# Batch :  8.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  59.07686185836792
# Batch :  9.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.116375207901
# Batch :  10.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.39345979690552
# Batch :  11.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.94258999824524
# Batch :  12.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.777583360672
# Loss at epoch  1 tensor(0.5949)
# Accuracy at epoch  1 tensor(1.)
# Epoch :  2
# Batch :  0.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.328938722610474
# Batch :  1.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.19783806800842
# Batch :  2.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.01583981513977
# Batch :  3.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.575196743011475
# Batch :  4.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.12217426300049
# Batch :  5.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.231287479400635
# Batch :  6.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.04538440704346
# Batch :  7.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.90508818626404
# Batch :  8.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.52961349487305
# Batch :  9.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.44086408615112
# Batch :  10.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.10362410545349
# Batch :  11.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.5408718585968
# Batch :  12.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  59.476707220077515
# Loss at epoch  2 tensor(0.5839)
# Accuracy at epoch  2 tensor(0.9667)
# Epoch :  3
# Batch :  0.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.1529643535614
# Batch :  1.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.021785736083984
# Batch :  2.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.81527256965637
# Batch :  3.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.08026051521301
# Batch :  4.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  59.7360897064209
# Batch :  5.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  59.103010416030884
# Batch :  6.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.64364814758301
# Batch :  7.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.406718730926514
# Batch :  8.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.164024114608765
# Batch :  9.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.21381735801697
# Batch :  10.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.50576043128967
# Batch :  11.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  59.669119358062744
# Batch :  12.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.0821750164032
# Loss at epoch  3 tensor(0.6021)
# Accuracy at epoch  3 tensor(0.9333)
# Epoch :  4
# Batch :  0.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.18500900268555
# Batch :  1.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.11570763587952
# Batch :  2.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.27846550941467
# Batch :  3.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.19910526275635
# Batch :  4.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.49334239959717
# Batch :  5.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.263258934020996
# Batch :  6.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.232271909713745
# Batch :  7.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  62.11701941490173
# Batch :  8.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.670124530792236
# Batch :  9.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.589436054229736
# Batch :  10.0
# Encryption of the training_batch took 4 seconds
# Time taken for this batch is :  61.569499254226685
# Batch :  11.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.75788879394531
# Batch :  12.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  62.396650075912476
# Loss at epoch  4 tensor(0.6070)
# Accuracy at epoch  4 tensor(0.9667)
# Epoch :  5
# Batch :  0.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.08076500892639
# Batch :  1.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.93726110458374
# Batch :  2.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.54363679885864
# Batch :  3.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.259544372558594
# Batch :  4.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.19967770576477
# Batch :  5.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.78376913070679
# Batch :  6.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.21276497840881
# Batch :  7.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.95206618309021
# Batch :  8.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.134655475616455
# Batch :  9.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  59.82806658744812
# Batch :  10.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  59.98400568962097
# Batch :  11.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.03058481216431
# Batch :  12.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.45329928398132
# Loss at epoch  5 tensor(0.6115)
# Accuracy at epoch  5 tensor(1.)
# Epoch :  6
# Batch :  0.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.45334315299988
# Batch :  1.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.91714906692505
# Batch :  2.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.70283126831055
# Batch :  3.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  59.596604347229004
# Batch :  4.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  59.443488359451294
# Batch :  5.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  59.56986904144287
# Batch :  6.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  59.29974818229675
# Batch :  7.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  59.46346139907837
# Batch :  8.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.40634751319885
# Batch :  9.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.00837182998657
# Batch :  10.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.768123626708984
# Batch :  11.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.75341534614563
# Batch :  12.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.152976989746094
# Loss at epoch  6 tensor(0.6110)
# Accuracy at epoch  6 tensor(1.)
# Epoch :  7
# Batch :  0.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.48907399177551
# Batch :  1.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.44303894042969
# Batch :  2.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  59.85715961456299
# Batch :  3.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.69851565361023
# Batch :  4.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  59.64753818511963
# Batch :  5.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.507587909698486
# Batch :  6.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.628153800964355
# Batch :  7.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.267780780792236
# Batch :  8.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.399543046951294
# Batch :  9.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.594929218292236
# Batch :  10.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  59.925968647003174
# Batch :  11.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.00800538063049
# Batch :  12.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.979674339294434
# Loss at epoch  7 tensor(0.6126)
# Accuracy at epoch  7 tensor(1.)
# Epoch :  8
# Batch :  0.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.59516358375549
# Batch :  1.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  59.92185616493225
# Batch :  2.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.79387354850769
# Batch :  3.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.8172881603241
# Batch :  4.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.015050649642944
# Batch :  5.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.45546245574951
# Batch :  6.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.0925669670105
# Batch :  7.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.335137605667114
# Batch :  8.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  59.70912718772888
# Batch :  9.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.34231686592102
# Batch :  10.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.954368114471436
# Batch :  11.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.897855281829834
# Batch :  12.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.536123752593994
# Loss at epoch  8 tensor(0.6124)
# Accuracy at epoch  8 tensor(1.)
# Epoch :  9
# Batch :  0.0
# Encryption of the training_batch took 4 seconds
# Time taken for this batch is :  62.28998160362244
# Batch :  1.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.181987047195435
# Batch :  2.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.872315406799316
# Batch :  3.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.92098903656006
# Batch :  4.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.64629578590393
# Batch :  5.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.2749764919281
# Batch :  6.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.12225890159607
# Batch :  7.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  61.35007071495056
# Batch :  8.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.22565317153931
# Batch :  9.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.50342035293579
# Batch :  10.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.87669372558594
# Batch :  11.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.90585160255432
# Batch :  12.0
# Encryption of the training_batch took 3 seconds
# Time taken for this batch is :  60.645851135253906
# Loss at epoch  9 tensor(0.6121)
# Accuracy at epoch  9 tensor(1.)
#
# Average time per epoch: 60 seconds
# Final weight1  [[-0.016347744281365404, -0.001415505836722293, 0.015251304891923447], [-0.03443410347348363, 0.007429721859460742, 0.010664424425559899], [-0.004893365475917111, -0.0028659395293982753, -0.001835206061820222], [-0.01506150804274811, -0.003092064733540307, -0.004209330739131519], [-0.02221825895284002, 0.01981564836386833, 0.0019850126921786815], [-0.01600525110026125, 0.017546559285025184, -0.0039543021006489725], [-0.018208920387267763, 0.0050802490597977755, -0.0008246778341732308], [-0.0025879018506758354, -0.005140446532063564, 0.0042708511066979465], [-0.002238272967760248, 0.00431412214287458, -0.009953096995878104], [-0.7844191311190851, -1.1092299804241523, -1.0209201353129675]]
# Final bias 1 [-0.06427022842148844, -0.013092418147766837, -0.03330243408515701]
# Final weight 2 [[-0.4195827475409372], [-0.8281763169782903], [-0.7394147222161737]]
# Final bias 2 [1.022394521390856]

# %%
j,k,l,r=eelr.forward(enc_x_train,ctx_training)
out=torch.tensor(enc_y_train.sub(j).decrypt().tolist())
correct=torch.abs(out)<0.5
print("Train Accuracy : ",correct.float().mean())
# Out:
# Train Accuracy :  tensor(1.)

# %%
enc_x_test = ts.ckks_tensor(ctx_training, x_test)
enc_y_test = ts.ckks_tensor(ctx_training, y_test)

# %%
m,n,j,k=eelr.forward(enc_x_test,ctx_training)
out=torch.tensor(enc_y_test.sub(m).decrypt().tolist())
correct=torch.abs(out)<0.5
print("Test Accuracy : ",correct.float().mean())
# Out:
# Test Accuracy :  tensor(1.)
